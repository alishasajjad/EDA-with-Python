# %% [markdown]
# # Exploratory Data Analysis

# %%
## EDA

## Exploratory Data Analysis 

## Exploratory Data Analysis (EDA) in Python is the foundational process of visualizing, cleaning, and summarizing a dataset to uncover patterns, detect anomalies, and check statistical assumptions before building machine learning models

##  A technique to extract insights from data 

## If you have data -> then making sense out of it, which is the definition of data science -> Exploring the data

## Data Analysis is something that allow us to Explore the daa and see what's inside it

# %% [markdown]
# ## Install Libraries

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## EDA Analysis Steps

# %% [markdown]
# ## 1. Import Libraries

# %%
# Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## First Specialty -> Exploring the data -> take a good look at the data

# %% [markdown]
# ## 2. Import Dataset

# %%
## Data Import

df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## 3. Explore Data (Bigger Picture of Data)

# %% [markdown]
# ### 3.1 Datatypes

# %%
# Understanding the Data
## First of all, we should know the data types

df.dtypes  

# output : ->  Types of Variables

## int64 -> numeric
## float -> numeric include decimal
## object -> double quality (categorical)
## class -> category -> first, second, third
## boolean -> true , false
## string -> text
# Out:
# survived          int64
# pclass            int64
# sex                 str
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked            str
# class          category
# who                 str
# adult_male         bool
# deck           category
# embark_town         str
# alive               str
# alone              bool
# dtype: object

# %% [markdown]
# ### 3.2 Information

# %%
df.info()

## Information which is very important -> RangeIndex: 891 entries, 0 to 890

## 3   age          714 non-null    float64 -> 891 - 714 = 177 -> Null Value (missing value)

## 11  deck         203 non-null    category -> 891 - 203 = 688 -> Null Value (missing value)

##  One step is to count missing values, or null values or NaN values

## Find Missing values is a common part of data analysis
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %% [markdown]
# ### 3.3 Missing Values

# %%
df.isnull().sum() #finding missing or null values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# df2 = df #44:00 min -> https://www.youtube.com/watch?v=sCdu54Mq0FA&list=PL9XvIvvVL50Fba7psesg6ynQXdipw-yoN

# %%
# df2

# %% [markdown]
# ### 3.4 Take Sense of your data

# %%
## Percentage of Null Values
df.isnull().sum() * 100/len(df) # % Calculation of missing values

# missing_Percentage = df.isnull().mean()*100 # another method to find percentage of missing values

# There are some rules in the world of data science, like every field has some rules, if this happen then this will happen 

## E.g -> deck           77.216611
## A rule which is in science -> if the value of a column is more than 70% or more than 75% -> that column become useless for your data -> or importing it or extracting anything else becomes useless -> but it depends on scenario

## It is a general rule 

## if you have this, it may contain any important information

## But usually what happen -> remove this column -> not bring it inside your data

## Usually -> more missing values column -> have important values also based on difference 

## E.g -> embarked        0.224467, embark_town     0.224467

# two,three,four missing  -> remove rows -> there are very few instances which are bad rows -> not remove this column 

# remove the entire row if data is not  fully impacted -> means not damaged


## E.g -> age            19.865320

# 19% missing values -> numeric values -> 3 to 4 methods to impute it -> impute -> wherever this missing values -> replace with the average of age column, or -> replace with median of age , or -> or replace with mode if it is categorical variable


## When approximately 30-40% of the data is missing -> then we try to impute 

## age good factor ahead -> they are dependent on each other
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# ## 4. How to deal with missing Values in EDA Analysis?

# %%
## How to deal with missing Values in EDA Analysis?
# Categorical/Object, Numeric(float, int), Boolean 

## Categorical/Object Data -> 
# Method 1: Fill with Mode -> Recommended
# Method 2: Fill with "Unknown" 
# Method 3: Forward Fill
# Method 4: Backward Fill

##  Numeric Data (int, float)
# Method 1: Fill with Mean -> Best for normally distributed data
# Method 2: Fill with Median ->  Recommended for Skewed Data
# Method 3: Fill with Constant
# Method 4: Interpolation

## Boolean Data
# Method 1: Fill with Mode
# Method 2: Fill with False
# Method 3: Fill with True

### NaN -> Not a Number 

## ->  we replace a numeric variable with mean -> because -> at least in the range

# %%
print(df['age'].max())
print(df['age'].min())  #when print word is missing -> then only one value is print in output, not both
# Out:
# 80.0
# 0.42

# %%
print(df['age'].mean())
# Out:
# 29.69911764705882

# %%
df['age'].unique() ## Unique Values of age column
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %% [markdown]
# ### 4.1 Replace NaN values with mean

# %%
## 1. Replace NaN values with mean

df2 = df['age'].fillna(df['age'].mean())
df2
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(), inplace=True) #now this syntax is not recommended in pandas version
## Updated Original Dataset by adding a -> inplace = True
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19132\782855999.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['age'].fillna(df['age'].mean(), inplace=True) #now this syntax is not recommended in pandas version
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
# ...

# %%
df.fillna({"age": df["age"].mean()}, inplace=True) # use this syntax
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df2 = df

# %%
df2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df2.isnull().sum()*100/len(df2)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age             0.000000
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
print(df2['age'].min())
print(df2['age'].max())
print(df2['age'].mean())
# Out:
# 0.42
# 80.0
# 29.69911764705882

# %%
df2['age'].unique()
# Out:
# array([22.        , 38.        , 26.        , 35.        , 29.69911765,
#        54.        ,  2.        , 27.        , 14.        ,  4.        ,
#        58.        , 20.        , 39.        , 55.        , 31.        ,
#        34.        , 15.        , 28.        ,  8.        , 19.        ,
#        40.        , 66.        , 42.        , 21.        , 18.        ,
#         3.        ,  7.        , 49.        , 29.        , 65.        ,
#        28.5       ,  5.        , 11.        , 45.        , 17.        ,
#        32.        , 16.        , 25.        ,  0.83      , 30.        ,
#        33.        , 23.        , 24.        , 46.        , 59.        ,
#        71.        , 37.        , 47.        , 14.5       , 70.5       ,
#        32.5       , 12.        ,  9.        , 36.5       , 51.        ,
#        55.5       , 40.5       , 44.        ,  1.        , 61.        ,
#        56.        , 50.        , 36.        , 45.5       , 20.5       ,
# ...

# %%
df2.fillna({"age": df2["age"].mean()}, inplace=True)
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df3 = df2

# %%
df3.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### 4.2 Drop Column

# %%
df3 = df3.drop(columns=["deck"])

# %%
df3
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
df3.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df4 = df3

# %% [markdown]
# ### 4.3 Replace Missing Values

# %%
df4.fillna({"embark_town": df4["embark_town"].mode()[0]}, inplace=True)
## embark_town -> categories replace with mode

df4.fillna({"embarked": df4["embarked"].mode()[0]}, inplace=True)
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
df4.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ## Mean, Median, Mode

# %%
## Mean, Median, Mode

# Mean: The average. Add all numbers together, then divide by the total count

# Median: The middle number. Order the numbers from smallest to largest and pick the exact middle
# 2,3,5,7 -> center 3,5 -> average of center -> 3+5/2 = 4 -> median = 4

# Mode: The most frequent number. The number that appears the most times in a data set
# 2,3,5,6,6,9,10,9 -> mode -> (6,9) -> (first mode, second mode) -> (index 0 , index 1)
# in code -> mode()[0] -> [0] -> means first mode which is 6

# %% [markdown]
# ## Data Wrangling

# %%
# Data wrangling, also known as data munging, is the essential process of transforming and mapping raw, messy data into a structured and valuable format ready for analytics

## Both Data Wrangling and Exploratory data analysis are running simultaneously

# %% [markdown]
# ## EDA and Wrangling

# %%
## Exploratory data analysis -> exploring data -> exploring means how many missing values are there 

## Wrangle -> how to deal with this(missing values)

# EDA = "What is wrong with my data?"
# Data Wrangling = "How do I fix my data?"

# %%
## EDA (Explore)	        Data Wrangling (Clean)
# Problem identify 	          Problem solve 
# Missing values count 	      Missing values fill/drop 
# Duplicates check 	          Duplicates remove 
# Outliers detect 	          Outliers treat/remove 
# Data Understanding	      Data Prepare for model

# %%
print("mean = ", df["age"].mean())
print("median = ", df["age"].median())
print("mode = ", df["age"].mode())

## mean and median -> near each other
# Out:
# mean =  29.69911764705882
# median =  29.69911764705882
# mode =  0    29.699118
# Name: age, dtype: float64

# %%
print("mode =", df["embark_town"].mode())
# Out:
# mode = 0    Southampton
# Name: embark_town, dtype: str

# %%
print("mode =", df["embarked"].mode())
# Out:
# mode = 0    S
# Name: embarked, dtype: str

# %%
## Two techniques Learn 

# 1. How to explore Data
# 2. How to Deal with it

# %%
df
# 1 row -> 1 person Data
# 0	0	3	male	22.000000	1	0	7.2500	S	Third	man	True	NaN	Southampton	no	False
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Understanding the all variables

# %%
## 14 variables 
# 13 variables data exist -> one is missing
# Impute missing one on the basis of other variables -> 
# if you can impute it -> this is called machine learning

## Data is also imputed on the basis of all the other variable interaction -> called machine learning imputation model

# %% [markdown]
# ## Steps: Data Wrangling

# %%
## Steps: Data Wrangling 

# 1. Import Libraries

# 2. Import Dataset

# 3. Explore your data
# ->  1. Information
# ->  2. Datatypes
# ->  3. Missing Values
# ->  4. Take Sense of your data

# 4. Understanding the all variables

# 5. Relationship between the Variables(Heatmap,Pairplot, Correlation)

# 6. Brainstorming ->  which way take data forward
# ->  1. Normalize -> a technique by which data or things are brought in similar units, they come closer to each other -> so that we can compare properly
# ->  Normalize things to compare with each other, and bring to closer so that the data becomes easy
# ->  2. Removing Outliers  -> something coming from outside or which does not belong to the data

# 7. Tidy data, Clean data
#                                        ^
####  80% of the time we do these things |


# 8. Ready for Statistical Analysis
# 9. Ready for Prediction
# 10. Ready for Machine Learning
# 11. Ready for Deep Learning

#                                         ^
#### # 20% of the time we do these things |

# %% [markdown]
# ## Rule  -> World of Data Science

# %%
## Rule  -> world of data science
# if we have 100 of data science work -> at least 80 hours of your data spend on data cleaning, data wrangling

# %% [markdown]
# ## Normalization Techniques

# %%
## Normalization Techniques

# 1. Min-Max Scaling
# 2. Standardization (Z-Score Scaling)
# 3. Robust Scaling
# 4. Max Absolute Scaling
# 5. Unit Vector Scaling (L1/L2 Normalization)

# %% [markdown]
# ## Outlier Detection & Removal Techniques

# %%
## Outlier Detection & Removal Techniques

## Detection Techniques
# 1. Box Plot
# 2. Scatter Plot
# 3. Histogram
# 4. IQR (Interquartile Range) Method ->  Most Common
# 5. Z-Score Method
# 6. Modified Z-Score
# 7. Percentile Method
# 8. Isolation Forest (Machine Learning)
# 9. Local Outlier Factor (LOF) (Machine Learning)
# 10. DBSCAN (Clustering-based)


## Outlier Handling Techniques

# 1. Remove Outliers -> Delete rows containing outliers
# 2. Capping / Winsorization -> Replace extreme values with upper/lower limits
# 3. Transformation
#    ->       Log Transformation
#    ->       Square Root Transformation
#    ->       Box-Cox Transformation
#    ->       Yeo-Johnson Transformation
# 4. Replace with Mean/Median -> In some cases, replace extreme values instead of removing them
# 5. Use Robust Models -> Use algorithms less sensitive to outliers (e.g., tree-based models)
